# %%
# %env KERAS_BACKEND=tensorflow
# Out:
# env: KERAS_BACKEND=tensorflow

# %% [markdown]
# # 引入套件

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ipywidgets import interact,IntSlider
#- - - - - - - - - - - - - - - - - - - - - - -

from keras.models import Sequential
from keras.layers.core import Dense,Activation
from keras.optimizers import SGD,Adam

from keras.datasets import mnist
from keras.utils import np_utils
from keras.utils import to_categorical

from keras.models import Model
from keras.layers import Input
from keras.layers import concatenate ,add

# %% [markdown]
# # 輸入手寫辨識資料集

# %%
(x_train0, y_train0), (x_test0, y_test0) = mnist.load_data()

# %%
print("There are %d training data with size %d x %d" %x_train0.shape)
print("There are %d testing  data with size %d x %d" %x_test0.shape)
# Out:
# There are 60000 training data with size 28 x 28
# There are 10000 testing  data with size 28 x 28

# %% [markdown]
# Reshape 資料大小

# %%
x_train = x_train0.reshape((60000,28*28))
x_test = x_test0.reshape((10000,28*28))

# %% [markdown]
# 對　 ｘ　做　Ｎｏｒｍａｌｉｚｅ

# %%
x_train -= x_train.min()
x_train = x_train/x_train.max()
#- - - - - - - - - - - - - - - - - - - - 
x_test -= x_test.min()
x_test = x_test/x_test.max()

# %%
x_train.min(), x_train.max()
# Out:
# (0.0, 1.0)

# %%
x_test.min(), x_test.max()
# Out:
# (0.0, 1.0)

# %% [markdown]
# 對　ｙ　做　ｏｎｅ　ｈｏｔ　ｅｎｃｏｄｉｎｇ

# %%
y_train = np_utils.to_categorical(y_train0, 10)
y_test = np_utils.to_categorical(y_test0, 10)

# %% [markdown]
# # 使用 Function API製作模型

# %% [markdown]
# ![Branch.PNG](attachment:Branch.PNG)

# %%
x = Input(shape=(784,))

# %%
#定義function
f_1 = Dense(200, activation='sigmoid')
f_2 = Dense(200, activation='sigmoid')
f_3 = Dense(200, activation='sigmoid')

f_4 = Dense(100, activation='relu')
f_5 = Dense(100, activation='relu')

f_6 = Dense(25, activation='relu')
f_7 = Dense(25, activation='relu')
f_8 = Dense(25, activation='relu')

lay_out= Dense(10, activation='softmax')

# %%
#統整 function
h_1 = f_1(x)
h_2 = f_2(x)
h_3 = f_3(x)

C_1 = concatenate([h_1,h_2,h_3])

h_4 = f_4(C_1)
h_5 = f_5(C_1)

C_2 = concatenate([h_4,h_5]) 

h_6 = f_6(C_2)
h_7 = f_7(C_2)
h_8 = f_8(C_2)

C_3 = concatenate([h_6,h_7,h_8])

y = lay_out(C_3)

# %%
model = Model(x,y)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 784)          0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 200)          157000      input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 200)          157000      input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 200)          157000      input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600)          0           dense_1[1][0]
#                                                                  dense_2[1][0]
#                                                                  dense_3[1][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 100)          60100       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 100)          60100       concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 200)          0           dense_4[1][0]
#                                                                  dense_5[1][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 25)           5025        concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 25)           5025        concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 25)           5025        concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 75)           0           dense_6[0][0]
#                                                                  dense_7[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 10)           760         concatenate_4[0][0]
# ==================================================================================================
# Total params: 607,035
# Trainable params: 607,035
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 訓練模型

# %%
model.compile(loss = 'mse',optimizer=Adam(lr=0.001),metrics = ["accuracy"])
model.fit(x_train, y_train, batch_size=1000, epochs=20, verbose=1, validation_data=(x_test, y_test))
# Out:
# WARNING:tensorflow:From C:\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0417 - acc: 0.7136 - val_loss: 0.0157 - val_acc: 0.9011
# Epoch 2/20
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0144 - acc: 0.9077 - val_loss: 0.0124 - val_acc: 0.9184
# Epoch 3/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0120 - acc: 0.9226 - val_loss: 0.0110 - val_acc: 0.9294
# Epoch 4/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0108 - acc: 0.9300 - val_loss: 0.0101 - val_acc: 0.9324
# Epoch 5/20
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0098 - acc: 0.9380 - val_loss: 0.0093 - val_acc: 0.9394
# Epoch 6/20
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0088 - acc: 0.9442 - val_loss: 0.0086 - val_acc: 0.9451
# Epoch 7/20
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0082 - acc: 0.9485 - val_loss: 0.0084 - val_acc: 0.9467
# Epoch 8/20
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0077 - acc: 0.9520 - val_loss: 0.0080 - val_acc: 0.9500
# Epoch 9/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0073 - acc: 0.9537 - val_loss: 0.0074 - val_acc: 0.9526
# Epoch 10/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0065 - acc: 0.9591 - val_loss: 0.0072 - val_acc: 0.9529
# Epoch 11/20
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0061 - acc: 0.9621 - val_loss: 0.0068 - val_acc: 0.9562
# Epoch 12/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0058 - acc: 0.9638 - val_loss: 0.0064 - val_acc: 0.9572
# Epoch 13/20
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0054 - acc: 0.9668 - val_loss: 0.0062 - val_acc: 0.9598
# Epoch 14/20
# 60000/60000 [==============================] - 2s 42us/step - loss: 0.0051 - acc: 0.9688 - val_loss: 0.0058 - val_acc: 0.9614
# Epoch 15/20
# 60000/60000 [==============================] - 2s 42us/step - loss: 0.0047 - acc: 0.9714 - val_loss: 0.0056 - val_acc: 0.9625
# Epoch 16/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0045 - acc: 0.9733 - val_loss: 0.0054 - val_acc: 0.9647
# Epoch 17/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0042 - acc: 0.9748 - val_loss: 0.0055 - val_acc: 0.9649
# Epoch 18/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0039 - acc: 0.9765 - val_loss: 0.0052 - val_acc: 0.9666
# Epoch 19/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.0038 - acc: 0.9777 - val_loss: 0.0049 - val_acc: 0.9680
# Epoch 20/20
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0035 - acc: 0.9790 - val_loss: 0.0049 - val_acc: 0.9680

# %%
score = model.evaluate(x_test, y_test)
print('model:')
print('loss:', score[0])
print('正確率:', score[1])
# Out:
# 10000/10000 [==============================] - 0s 46us/step
# model:
# loss: 0.0048750227503136555
# 正確率: 0.968
